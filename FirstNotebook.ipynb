# %% [markdown]
# <a href="https://colab.research.google.com/github/kavisha-jay/MelojiMix/blob/main/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  ***Data Manipulations***
# ---

# %% [markdown]
# ---

# %% [markdown]
# 1.   Import the pandas library using the shorthand pd
# 2.   Read the CSV file using pd.read_csv.
# 3.   Load the data into a DataFrame

# %%
#Importing pandas library
import pandas as pd

#Loading data into a DataFrame
data_frame=pd.read_csv('/content/drive/MyDrive/ML_TUTORIALS/Mall_Customers.csv')

# %% [markdown]
# ---

# %% [markdown]
# 1.              data_frame.head() displays the
# first five rows
# 2.          data_frame.tail() displays the last five rows
# 3.              To get the first 'n' rows of a DataFrame, use: data_frame.head(n)
# 4.              To get the last 'n' rows of a DataFrame, use: data_frame.tail(n)

# %%
#displaying first five rows
data_frame.head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0

# %%
#displaying last five rows
data_frame.tail()
# Out:
#      CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female  35.0               120.0                    79.0
# 196         197  Female  45.0               126.0                    28.0
# 197         198    Male  32.0               126.0                    74.0
# 198         199    Male  32.0               137.0                    18.0
# 199         200    Male  30.0               137.0                    83.0

# %%
#displaying first ten rows
data_frame.head(10)
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0
# 5           6  Female  22.0                17.0                    76.0
# 6           7  Female   NaN                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     3.0
# 9          10  Female  30.0                19.0                    72.0

# %% [markdown]
# ---

# %% [markdown]
# To display the column names of a DataFrame, use the list function.

# %%
#Program to print all the column names of the data_frame
list(data_frame.columns)
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']
